# %%
# %run v1Network.ipynb

# %%
supperImpose('arbors/001_1_C_day3.csv', -.8, 0)
supperImpose('arbors/001_1_C_day3.csv', -.1, 0)
supperImpose('arbors/001_1_C_day3.csv', 0, 0)
supperImpose('arbors/001_1_C_day3.csv', -.9, 0.5)
supperImpose('arbors/001_1_C_day3.csv', -.6, 1)
# Out:
# optimal and original super imposed given: G= -0.8 , alpha= 0
# optimal and original super imposed given: G= -0.1 , alpha= 0
# optimal and original super imposed given: G= 0 , alpha= 0
# optimal and original super imposed given: G= -0.9 , alpha= 0.5
# optimal and original super imposed given: G= -0.6 , alpha= 1
