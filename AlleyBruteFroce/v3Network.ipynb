# %%
# %run v1Network.ipynb  
import numpy as np

# %%
Grange = np.arange(-0.1,.1,.1)
aRange= np.arange(0,.2,.1)
for G in Grange:
    for alpha in aRange:
        supperImpose('arbors/001_1_C_day3.csv', G, alpha)
# Out:
# optimal and original super imposed given: G= -0.1 , alpha= 0.0
# optimal and original super imposed given: G= -0.1 , alpha= 0.1
# optimal and original super imposed given: G= 0.0 , alpha= 0.0
# optimal and original super imposed given: G= 0.0 , alpha= 0.1
